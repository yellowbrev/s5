# %%
import pandas as pd

# Creating the DataFrame
data = {
    'Name': ['Mudit Chauhan', 'Seema Chopra', 'Rani Gupta', 'Aditya Narayan', 'Sanjeev Sahni',
             'Prakash Kumar', 'Ritu Agarwal', 'Akshay Goel', 'Meeta Kulkarni', 'Preeti Ahuja',
             'Sunil Das Gupta', 'Sonali Sapre', 'Rashmi Talwar', 'Ashish Dubey', 'Kiran Sharma',
             'Sameer Bansal'],
    'Birth_Month': ['December', 'January', 'March', 'October', 'February', 'December', 'September',
                    'August', 'July', 'November', 'April', 'January', 'June', 'May', 'February',
                    'October'],
    'Gender': ['M', 'F', 'F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'F', 'F', 'M', 'F', 'M'],
    'Pass_Division': ['III', 'II', 'I', 'I', 'II', 'III', 'I', 'I', 'II', 'II', 'III', 'I', 'III', 'II', 'II', 'I']
}

df = pd.DataFrame(data)

# a. Perform one-hot encoding of the last two columns
df_encoded = pd.get_dummies(df, columns=['Gender', 'Pass_Division'], prefix=['Gender', 'Division'])
print(df_encoded)

# b. Sort the DataFrame based on the "Birth_Month" column
months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df_encoded['Birth_Month'] = pd.Categorical(df_encoded['Birth_Month'], categories=months_order, ordered=True)
df_encoded = df_encoded.sort_values(by='Birth_Month')
print(df_encoded)
# Out:
#                Name Birth_Month  Gender_F  Gender_M  Division_I  Division_II  \
# 0     Mudit Chauhan    December     False      True       False        False
# 1      Seema Chopra     January      True     False       False         True
# 2        Rani Gupta       March      True     False        True        False
# 3    Aditya Narayan     October     False      True        True        False
# 4     Sanjeev Sahni    February     False      True       False         True
# 5     Prakash Kumar    December     False      True       False        False
# 6      Ritu Agarwal   September      True     False        True        False
# 7       Akshay Goel      August     False      True        True        False
# 8    Meeta Kulkarni        July      True     False       False         True
# 9      Preeti Ahuja    November      True     False       False         True
# 10  Sunil Das Gupta       April     False      True       False        False
# 11     Sonali Sapre     January      True     False        True        False
# 12    Rashmi Talwar        June      True     False       False        False
# 13     Ashish Dubey         May     False      True       False         True
# 14     Kiran Sharma    February      True     False       False         True
# 15    Sameer Bansal     October     False      True        True        False
#
#     Division_III
# 0           True
# 1          False
# 2          False
# 3          False
# 4          False
# 5           True
# 6          False
# 7          False
# 8          False
# 9          False
# 10          True
# 11         False
# 12          True
# 13         False
# 14         False
# 15         False
#                Name Birth_Month  Gender_F  Gender_M  Division_I  Division_II  \
# 1      Seema Chopra     January      True     False       False         True
# 11     Sonali Sapre     January      True     False        True        False
# 4     Sanjeev Sahni    February     False      True       False         True
# 14     Kiran Sharma    February      True     False       False         True
# 2        Rani Gupta       March      True     False        True        False
# 10  Sunil Das Gupta       April     False      True       False        False
# 13     Ashish Dubey         May     False      True       False         True
# 12    Rashmi Talwar        June      True     False       False        False
# 8    Meeta Kulkarni        July      True     False       False         True
# 7       Akshay Goel      August     False      True        True        False
# 6      Ritu Agarwal   September      True     False        True        False
# 3    Aditya Narayan     October     False      True        True        False
# 15    Sameer Bansal     October     False      True        True        False
# 9      Preeti Ahuja    November      True     False       False         True
# 0     Mudit Chauhan    December     False      True       False        False
# 5     Prakash Kumar    December     False      True       False        False
#
#     Division_III
# 1          False
# 11         False
# 4          False
# 14         False
# 2          False
# 10          True
# 13         False
# 12          True
# 8          False
# 7          False
# 6          False
# 3          False
# 15         False
# 9          False
# 0           True
# 5           True
